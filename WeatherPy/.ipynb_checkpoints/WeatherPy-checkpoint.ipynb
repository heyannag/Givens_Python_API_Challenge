# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib as mpl
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

url = "http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=" + weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
city_weather_request_url = url + "&q=" + city
print(city_weather_request_url)
    
response = requests.get(city_weather_request_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=metric&APPID=9af9fd90c908660acbefdce2a0b2a7dd&q=omaruru

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
city_df = pd.read_csv('output_data/cities.csv')
city_df
# Out:
#      City_ID         City  Cloudiness Country        Date  Humidity    Lat  \
# 0          0    ostrovnoy           2      RU  1558378754        72  68.05
# 1          1    mahebourg          75      MU  1558378503        74 -20.41
# 2          2      qaanaaq          25      GL  1558378755        73  77.48
# 3          3       zhuhai           0      CN  1558378755        39  40.71
# 4          4    cape town          20      ZA  1558378755        76 -33.93
# ..       ...          ...         ...     ...         ...       ...    ...
# 543      543       yabrud           0      SY  1558378840        32  33.97
# 544      544      paraiso           5      MX  1558378898         4  24.01
# 545      545      veraval           0      FR  1558378898        62  49.65
# 546      546  novyy urgal         100      RU  1558378899        93  51.07
# 547      547      tongren           4      CN  1558378899        64  27.72
#
#         Lng  Max Temp  Wind Speed
# ...

# %% [markdown]
# ## GOAL: Write a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator.

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Max Temp"], marker="*", 
           c ='olive')

# Incorporate the other graph properties
plt.title("Temperature (F) vs. Latitude")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("PNG_Files/Temp_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Humidity"],c='yellowgreen', marker="d")

# Incorporate the other graph properties
plt.title("Humidity (%) vs. Latitude")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("PNG_Files/Humidity_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Cloudiness"],c='lightseagreen', marker="+")

# Incorporate the other graph properties
plt.title("Cloudiness (%) vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("PNG_Files/Cloudiness_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(city_df["Lat"], city_df["Wind Speed"],c='forestgreen', marker=".")

# Incorporate the other graph properties
plt.title("Wind Speed (mph) vs. Latitude")
plt.ylabel("Wind Speed")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("PNG_Files/WindSpeed_vs_Lat.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# Make a function that accepts a list of x values and y values, a description for the x and y axes,
# a string that describes which hemisphere is being analyzed and a filename to use while saving the figure
# and finally the x,y coordinates to create the annotation of the equation on the graph
def plotLinearRegression(xdata,ydata,xlbl,ylbl,lblpos,ifig):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(xdata, ydata)
    print(f"The r-squared is: {rvalue}")
    regress_values = xdata * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    plt.scatter(xdata,ydata)
    plt.plot(xdata,regress_values,"r-")
    plt.annotate(line_eq,lblpos,fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    plt.savefig(f'PNG_Files/Linear_Regression{ifig}.png')
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
nothern = city_df.loc[city_df["Lat"] >= 0.0]
nothern.reset_index(inplace=True)

southern = city_df.loc[city_df["Lat"] < 0.0]
southern.reset_index(inplace=True)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - Max Temp vs Latitude Line Regression')
x_label = "Lat"
y_label = "Max Temp"
label_pos = (0,15)
plotLinearRegression(nothern[x_label],nothern[y_label],x_label,y_label,label_pos,5)
# Out:
# The r-squared is: -0.8151657406810829

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')
x_label = "Lat"
y_label = "Max Temp"
label_pos = (40,100)
plotLinearRegression(southern[x_label],southern[y_label],x_label,y_label,label_pos,6)
# Out:
# The r-squared is: 0.7602633550516462

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
x_label = "Lat"
y_label = "Humidity"
label_pos = (45,10)
plotLinearRegression(nothern[x_label],nothern[y_label],x_label,y_label,label_pos,7)
# Out:
# The r-squared is: 0.10358336015746496

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression')
x_label = "Lat"
y_label = "Humidity"
label_pos = (-50,150)
plotLinearRegression(southern[x_label],southern[y_label],x_label,y_label,label_pos,8)
# Out:
# The r-squared is: 0.14689473425583074

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (15,60)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,9)
# Out:
# The r-squared is: -0.08733547918934018

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression')
xlbl = "Lat"
ylbl = "Cloudiness"
lblpos = (-52,25)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,10)
# Out:
# The r-squared is: 0.21881426893991604

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title('Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (32,26)
plotLinearRegression(nothern[xlbl],nothern[ylbl],xlbl,ylbl,lblpos,11)
# Out:
# The r-squared is: 0.10713827743884798

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.title('Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression')
xlbl = "Lat"
ylbl = "Wind Speed"
lblpos = (-25,25)
plotLinearRegression(southern[xlbl],southern[ylbl],xlbl,ylbl,lblpos,12)
# Out:
# The r-squared is: -0.3224830771395381
